# %% [markdown]
# # Python For Data Science

# %% [markdown]
# ### Python is a case sensitive langugage

# %% [markdown]
# ### How to print in Python

# %%
print("Hello Prince Parmar")
print('salman khan')

# %%
print(7.7)

print('Hello',1,4,5,True,sep='/')

#space reading manual like sep=''

print('Hello',1,4,5,True,sep='/')

#
print('hello', end='_')
print('world')


# Data Types
#Integer
print(8)
print(1e308)

print(8.55)

# Decimal/Float
print(8.55)
print(1.7e309)

#Boolean 
print(True)
print(False)

#Text /String
print('hello world')

#Complex Number
print(5+6j)

# list -> C -> Array
print([1,2,3,4,5])

#Tuple
print((1,2,3,4,5))

#Sets
print({1,2,3,4,5})

# Dictionary
print({'name':'nitish','gender':'male','weight':70})

#type function
type(3)
type(3.5)

#Variables
#c/c++ int name ='nitish'

name ='prince'
print(name)
a = 5
b = 6
print(a+b)

#Dynamic Typing
a = 5

# Static Typing Static Binding follow in c/c++ they support Static Binding
# int a = 5

#Dynamic Binding 
a = 5
print(a)
a = 'nitish'
print(a)

# %% [markdown]
# ## 4 Keywords and Identifiers

# %%
# Keywords 32 keywords in python like False None True etc..

# Identifiers 
# Some rules and regulation to write the python code
# Rule no1 : not start the number like 1name;
# 1name='prince'
# Rule no2 : you can use special chars-> _ like example
_ = 'nitish'
print(_)
first_name='prince'
print(first_name)

# %% [markdown]
# ## 5. User Input

# %%
# # Static Vs Dynamic
# # input()
# fnum = int(input('enter first number'))
# snum = int(input('enter second number'))
# # add  the two variables
# result = fnum + snum
# print(result)

# %% [markdown]
# ## 6. Literals

# %%
a = 0b1010 #Binary literals
b = 100 # Decimal Literal
c = 0o310 # octal literal
d = 0x12c #Hexadecimal Literal

# Float literal
float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5-3

#complex literal
x = 3.14j
print(a , b, c, d)
print(float_1, float_2, float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 -1.5
# 3.14j 3.14 0.0

# %% [markdown]
# ## 7. String

# %%
string = 'This is Python'
strings = 'this is Python'
multiline_str = """This is a multiline string with more than one line code"""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"
print(string)
print(strings)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# this is Python
# This is a multiline string with more than one line code
# 😀😆🤣
# raw \n string

# %%
a = None
print(a)
