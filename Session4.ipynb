# %% [markdown]
# ## Lists

# %% [markdown]
# ### List , what are lists?, lists vs arrays, charcaterstics of a list, how to create a list,access items from a list , editing items in a list, deleting items from a list, operation on lists, function on lists
